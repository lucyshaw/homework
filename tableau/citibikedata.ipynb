# %%
import pandas as pd

# %%
df1 = pd.read_csv('2017Q1.csv')
df2 = pd.read_csv('2017Q2.csv')
df3 = pd.read_csv('2017Q3.csv')
df4 = pd.read_csv('2017Q4.csv')
df5 = pd.read_csv('2018Q1.csv')
df6 = pd.read_csv('2018Q2.csv')
df7 = pd.read_csv('2018Q3.csv')
df8 = pd.read_csv('2018Q4.csv')
df9 = pd.read_csv('2019Q1.csv')

# %%
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9]

# %%
full_data = pd.concat(frames)
full_data.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/17                                              16009
# 1  1/2/17                                               8921
# 2  1/3/17                                              14198
# 3  1/4/17                                              34039
# 4  1/5/17                                              28393
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        50761
# 1                                        21545
# 2                                        25879
# 3                                        69966
# 4                                        52446
#
#    Total Annual Members (All Time)  \
# 0                           206624
# 1                           206675
# 2                           206728
# 3                           206778
# 4                           206845
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
full_data.to_csv('../homework/tableau/membership_data.csv')

# %%
rides1 = pd.read_csv('ridedata/201701-citibike-tripdata.csv')
rides2 = pd.read_csv('ridedata/201702-citibike-tripdata.csv')
rides3 = pd.read_csv('ridedata/201703-citibike-tripdata.csv')
rides4 = pd.read_csv('ridedata/201704-citibike-tripdata.csv')
rides5 = pd.read_csv('ridedata/201705-citibike-tripdata.csv')
rides6 = pd.read_csv('ridedata/201706-citibike-tripdata.csv')
rides7 = pd.read_csv('ridedata/201707-citibike-tripdata.csv')
rides8 = pd.read_csv('ridedata/201708-citibike-tripdata.csv')
rides9 = pd.read_csv('ridedata/201709-citibike-tripdata.csv')
rides10 = pd.read_csv('ridedata/201710-citibike-tripdata.csv')
rides11 = pd.read_csv('ridedata/201711-citibike-tripdata.csv')
rides12 = pd.read_csv('ridedata/201712-citibike-tripdata.csv')
rides13 = pd.read_csv('ridedata/201801-citibike-tripdata.csv')
rides14 = pd.read_csv('ridedata/201802-citibike-tripdata.csv')
rides15 = pd.read_csv('ridedata/201803-citibike-tripdata.csv')
rides16 = pd.read_csv('ridedata/201804-citibike-tripdata.csv')
rides17 = pd.read_csv('ridedata/201805-citibike-tripdata.csv')
rides18 = pd.read_csv('ridedata/201806-citibike-tripdata.csv')
rides19 = pd.read_csv('ridedata/201807-citibike-tripdata.csv')
rides20 = pd.read_csv('ridedata/201808-citibike-tripdata.csv')
rides21 = pd.read_csv('ridedata/201809-citibike-tripdata.csv')
rides22 = pd.read_csv('ridedata/201810-citibike-tripdata.csv')
rides23 = pd.read_csv('ridedata/201811-citibike-tripdata.csv')
rides24 = pd.read_csv('ridedata/201812-citibike-tripdata.csv')
rides25 = pd.read_csv('ridedata/201901-citibike-tripdata.csv')
rides26 = pd.read_csv('ridedata/201902-citibike-tripdata.csv')
rides27 = pd.read_csv('ridedata/201903-citibike-tripdata.csv')

# %%
rides = [rides22, rides23, rides24, rides25, rides26, rides27]

# %%
ride_data = pd.concat(rides)
ride_data
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 330  2018-10-01 00:00:00.7010  2018-10-01 00:05:30.8490
# 1                 309  2018-10-01 00:00:13.5780  2018-10-01 00:05:23.2310
# 2                 734  2018-10-01 00:00:16.6040  2018-10-01 00:12:31.5050
# 3                 788  2018-10-01 00:00:35.0670  2018-10-01 00:13:43.5780
# 4                1136  2018-10-01 00:00:38.1410  2018-10-01 00:19:34.6490
# 5                 623  2018-10-01 00:00:39.0770  2018-10-01 00:11:02.7910
# 6                 498  2018-10-01 00:00:45.6350  2018-10-01 00:09:04.4050
# 7                 103  2018-10-01 00:00:49.1740  2018-10-01 00:02:32.5410
# 8                 484  2018-10-01 00:00:55.9960  2018-10-01 00:09:00.5120
# 9                 252  2018-10-01 00:01:01.8550  2018-10-01 00:05:14.6200
# 10                583  2018-10-01 00:01:03.0260  2018-10-01 00:10:46.1460
# 11               1099  2018-10-01 00:01:06.8940  2018-10-01 00:19:26.7230
# ...

# %%
ride_data.to_csv('../homework/tableau/rides3.csv')
